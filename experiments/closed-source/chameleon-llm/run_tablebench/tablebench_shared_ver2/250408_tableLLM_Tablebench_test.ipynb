# %%
from datasets import Dataset, load_dataset
import pandas as pd
import json

# %%
dataset = load_dataset("Multilingual-Multimodal-NLP/TableBench", trust_remote_code=True)
dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['id', 'qtype', 'qsubtype', 'instruction', 'instruction_type', 'table', 'question', 'answer', 'answer_formatter', 'chart_type'],
#         num_rows: 2658
#     })
# })

# %%
dataset['test']
# Out:
# Dataset({
#     features: ['id', 'qtype', 'qsubtype', 'instruction', 'instruction_type', 'table', 'question', 'answer', 'answer_formatter', 'chart_type'],
#     num_rows: 2658
# })

# %% [markdown]
# # Test dataloader

# %%
from Tablebench_loader import Tablebench_Filtered
index = 1709
Tablebench = Tablebench_Filtered(dataset, index) 
Tablebench_table = Tablebench.get_table()
Tablebench_question = Tablebench.get_question()
Tablebench_answer = Tablebench.get_answer()
Tablebench_qsubtype = Tablebench.get_qsubtype()

# %%
Tablebench_table
# Out:
#          artist  jaanu någisto  iiris vesik  erik morna  veronika portsmuth  \
# 0  ithaka maria              4            4           3                   9
# 1   rolf junior              8            7           7                   1
# 2    orelipoiss              1            5          10                  10
# 3  getter jaani              9            9           6                   5
# 4     jana kask              6            6           5                   6
# 5           mid              3            1           9                   7
# 6      outloudz             10           10           8                   8
# 7       mimicry              5            3           1                   4
# 8       noorkuu              7            2           2                   3
#
#    chalice  kristo rajasaare  hannaliisa uusmaa  siim nestor  peeter vã¤hi  \
# 0        6                 2                  3            5             6
# ...

# %%
table_str = Tablebench_table.to_string(index=False).replace('\n ', '\n')  # Clean up formatting
table_str
# Out:
# 'tribunal number of autos da fé with known sentences executions in persona executions in effigie       penanced        total\n lisbon                          248 (1540 - 1794)                   461                   181           7024         7666\n  évora                          164 (1536 - 1781)                   344                   163           9466         9973\ncoimbra                          277 (1541 - 1781)                   313                   234           9000         9547\n    goa                           71 (1600 - 1773)                    57                    64           4046         4167\n  tomar                            2 (1543 - 1544)                     4                     0             17           21\n  porto                                   1 (1543)                     4                    21             58           83\n lamego                                          0                     0                     0              0            0\n  to
# ...

# %%
Tablebench_question
# Out:
# "Which color combination has a higher 'Pin (Tip)' value, White/Blue or Red/Blue?"

# %%
print(Tablebench_answer)
# Out:
# Red/Blue

# %%
Tablebench_qsubtype
# Out:
# 'Comparison'

# %%
index = 1779
Tablebench = Tablebench_Filtered(dataset, index) # index upto 1778
Tablebench_table = Tablebench.get_table()
Tablebench_question = Tablebench.get_question()
Tablebench_answer = Tablebench.get_answer()
Tablebench_qsubtype = Tablebench.get_qsubtype()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 index = 1779
#       2 Tablebench = Tablebench_Filtered(dataset, index) # index는 1778까지 있음. 1779부터 out of index
# ----> 3 Tablebench_table = Tablebench.get_table()
#       4 Tablebench_question = Tablebench.get_question()
#       5 Tablebench_answer = Tablebench.get_answer()
#
# File ~\Desktop\tablebench_shared_error\Tablebench_loader.py:21, in Tablebench_Filtered.get_table(self)
#      19 def get_table(self):
#      20     """테이블(DataFrame) 반환"""
# ---> 21     data_dict = json.loads(self.dataset['table'][self.index])
#      22     df = pd.DataFrame(data=data_dict["data"], columns=data_dict["columns"])
#      23     return df
#
# IndexError: list index out of range

# %% [markdown]
# # exact match

# %%
from evaluate import *
text1 = "34.49999999999%"
text2 = "34.5"

check = check_exact_match(text1, text2)
check
# Out:
# C:\Users\zxc26\anaconda3\envs\ml\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# True
