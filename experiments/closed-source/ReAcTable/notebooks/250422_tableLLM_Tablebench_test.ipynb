# %%
from datasets import Dataset, load_dataset
import pandas as pd
import json

# %%
dataset = load_dataset(path="Multilingual-Multimodal-NLP/TableBench", data_files="TableBench.jsonl", split="train")
dataset
# Out:
# Dataset({
#     features: ['id', 'qtype', 'qsubtype', 'table', 'question', 'answer', 'chart_type'],
#     num_rows: 886
# })

# %% [markdown]
# # Test dataloader

# %%
from Tablebench_loader import Tablebench_Filtered
index = 692
Tablebench = Tablebench_Filtered(dataset, index) # index는 692까지 있음. 693부터 out of index
Tablebench_table = Tablebench.get_table()
Tablebench_question = Tablebench.get_question()
Tablebench_answer = Tablebench.get_answer()
Tablebench_qsubtype = Tablebench.get_qsubtype()

# %%
Tablebench_table
# Out:
#             Color Pin (Tip) Pin (Ring)        Color.1
# 0      White/Blue        26          1     Blue/White
# 1    White/Orange        27          2   Orange/White
# 2     White/Green        28          3    Green/White
# 3     White/Brown        29          4    Brown/White
# 4     White/Slate        30          5    Slate/White
# 5        Red/Blue        31          6       Blue/Red
# 6      Red/Orange        32          7     Orange/Red
# 7       Red/Green        33          8      Green/Red
# 8       Red/Brown        34          9      Brown/Red
# 9       Red/Slate        35         10      Slate/Red
# 10     Black/Blue        36         11     Blue/Black
# 11   Black/Orange        37         12   Orange/Black
# 12    Black/Green        38         13    Green/Black
# 13    Black/Brown        39         14    Brown/Black
# 14    Black/Slate        40         15    Slate/Black
# 15    Yellow/Blue        41         16    Blue/Yellow
# 16  Yellow/Orange        42         17  Orange/Yellow
# 17   Yellow/Green        43         18   Green/Yellow
# 18   Yellow/Brown        44         19   Brown/Yellow
# 19   Yellow/Slate        45         20   Slate/Yellow
# 20    Violet/Blue        46         21    Blue/Violet
# 21  Violet/Orange        47         22  Orange/Violet
# 22   Violet/Green        48         23   Green/Violet
# 23   Violet/Brown        49         24   Brown/Violet
# 24   Violet/Slate        50         25   Slate/Violet

# %%
Tablebench_question
# Out:
# "Which color combination has a higher 'Pin (Tip)' value, White/Blue or Red/Blue?"

# %%
print(Tablebench_answer)
# Out:
# Red/Blue

# %%
Tablebench_qsubtype
# Out:
# 'Comparison'

# %%
index = 693
Tablebench = Tablebench_Filtered(dataset, index) # index는 692까지 있음. 693부터 out of index
Tablebench_table = Tablebench.get_table()
Tablebench_question = Tablebench.get_question()
Tablebench_answer = Tablebench.get_answer()
Tablebench_qsubtype = Tablebench.get_qsubtype()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 index = 693
#       2 Tablebench = Tablebench_Filtered(dataset, index) # index는 692까지 있음. 693부터 out of index
# ----> 3 Tablebench_table = Tablebench.get_table()
#       4 Tablebench_question = Tablebench.get_question()
#       5 Tablebench_answer = Tablebench.get_answer()
#
# File ~\Desktop\EMNLP2025_ver4\tablebench_shared_ver4\Tablebench_loader.py:28, in Tablebench_Filtered.get_table(self)
#      27 def get_table(self):
# ---> 28     data_dict = self.dataset['table'][self.index]
#      29     df = pd.DataFrame(data=data_dict["data"], columns=data_dict["columns"])
#      30     return df
#
# IndexError: list index out of range

# %% [markdown]
# # exact match 사용법

# %%
from evaluate import *
text1 = "34.49999999999%"
text2 = "34.5"

check = check_exact_match(text1, text2)
check
# Out:
# C:\Users\zxc26\anaconda3\envs\ml\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# True
